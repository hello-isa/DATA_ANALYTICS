# %% [markdown]
# # Select Dataset

# %% [markdown]
# * Forest Fires: https://archive.ics.uci.edu/dataset/162/forest+fires
# * This is a difficult regression task, where the aim is to predict the burned area of forest fires, in the northeast region of Portugal, by using meteorological and other data (see details at: http://www.dsi.uminho.pt/~pcortez/forestfires).

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
forest_fires = fetch_ucirepo(id=162) 
  
# data (as pandas dataframes) 
X = forest_fires.data.features 
y = forest_fires.data.targets 
  
# metadata 
print(forest_fires.metadata) 
  
# variable information 
print(forest_fires.variables)
# Out:
# {'uci_id': 162, 'name': 'Forest Fires', 'repository_url': 'https://archive.ics.uci.edu/dataset/162/forest+fires', 'data_url': 'https://archive.ics.uci.edu/static/public/162/data.csv', 'abstract': 'This is a difficult regression task, where the aim is to predict the burned area of forest fires, in the northeast region of Portugal, by using meteorological and other data (see details at: http://www.dsi.uminho.pt/~pcortez/forestfires).', 'area': 'Climate and Environment', 'tasks': ['Regression'], 'characteristics': ['Multivariate'], 'num_instances': 517, 'num_features': 12, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['area'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2007, 'last_updated': 'Thu Jan 11 2024', 'dataset_doi': '10.24432/C5D88D', 'creators': ['Paulo Cortez', 'Anbal Morais'], 'intro_paper': {'title': 'A data mining approach to predict forest fires using meteorological data', 'authors': 'P. Cortez,
# ...

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Concatenate features (X) and target (y) into a DataFrame
df = pd.concat([X, y], axis=1)
print(df)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %% [markdown]
# # Perform Regression Analysis

# %%
# Apply dummy coding to categorical variables
dummy_df = pd.get_dummies(df, columns=['month', 'day'])

print(dummy_df)
# Out:
#      X  Y  FFMC    DMC     DC   ISI  temp  RH  wind  rain  ...  month_nov  \
# 0    7  5  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0  ...      False
# 1    7  4  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0  ...      False
# 2    7  4  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0  ...      False
# 3    8  6  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2  ...      False
# 4    8  6  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0  ...      False
# ..  .. ..   ...    ...    ...   ...   ...  ..   ...   ...  ...        ...
# 512  4  3  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0  ...      False
# 513  2  4  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  ...      False
# 514  7  4  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  ...      False
# 515  1  4  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0  ...      False
# 516  6  3  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0  ...       True
#
#      month_oct  month_sep  day_fri  day_mon  day_sat  day_sun  day_thu  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(dummy_df.drop(columns=['area']))  # Exclude the target variable
scaled_df = pd.DataFrame(scaled_features, columns=dummy_df.drop(columns=['area']).columns)

# Concatenate scaled features and target
final_df = pd.concat([scaled_df, dummy_df['area']], axis=1)

print(final_df)
# Out:
#             X         Y      FFMC       DMC        DC       ISI      temp  \
# 0    1.008313  0.569860 -0.805959 -1.323326 -1.830477 -0.860946 -1.842640
# 1    1.008313 -0.244001 -0.008102 -1.179541  0.488891 -0.509688 -0.153278
# 2    1.008313 -0.244001 -0.008102 -1.049822  0.560715 -0.509688 -0.739383
# 3    1.440925  1.383722  0.191362 -1.212361 -1.898266 -0.004756 -1.825402
# 4    1.440925  1.383722 -0.243833 -0.931043 -1.798600  0.126966 -1.291012
# ..        ...       ...       ...       ...       ...       ...       ...
# 512 -0.289524 -1.057862 -1.640083 -0.846648  0.474768 -1.563460  1.536084
# 513 -1.154748 -0.244001 -1.640083 -0.846648  0.474768 -1.563460  0.519019
# 514  1.008313 -0.244001 -1.640083 -0.846648  0.474768 -1.563460  0.398350
# 515 -1.587360 -0.244001  0.680957  0.549003  0.269382  0.500176  1.156839
# 516  0.575701 -1.057862 -2.020879 -1.685913 -1.780442 -1.739089 -1.222058
#
#            RH      wind      rain  ...  month_oct  month_sep   day_fri  \
# ...

# %% [markdown]
# ## Visulization
# * Visualize the relationship and assess whether a linear or polynomial model is more appropriate.
# * **Scatter plots** to visualize the raw data and assess the relationship between variables.
# * **Fitted curves** to visualize how well the model fits the data and captures the underlying pattern.

# %% [raw]
# # Scatter plots
# sns.pairplot(df, x_vars=['X', 'Y', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain'],
#              y_vars=['area'], kind='scatter')
# plt.show()

# %%
# Select columns of interest
selected_columns = ['X', 'Y', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain']

# %%
# Scatter plots
sns.pairplot(final_df, x_vars=selected_columns, y_vars=['area'], kind='scatter')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# Fitted curves - Simple Linear Regression
for feature in selected_columns:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=scaled_df[feature], y=final_df['area'], color='blue', alpha=0.5)
    sns.regplot(x=scaled_df[feature], y=final_df['area'], scatter=False, color='red', order=1, ci=None, label='Linear')
    plt.xlabel(feature)
    plt.ylabel('Area')
    plt.legend()
    plt.title(f'Fitted Curve - {feature} vs. Area (Linear)')
    plt.show()

# Fitted curves - Polynomial Regression (e.g., quadratic)
for feature in selected_columns:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=scaled_df[feature], y=final_df['area'], color='blue', alpha=0.5)
    
    # Polynomial regression
    polynomial_features = PolynomialFeatures(degree=2)
    X_poly = polynomial_features.fit_transform(scaled_df[[feature]])
    poly_model = LinearRegression()
    poly_model.fit(X_poly, final_df['area'])
    y_poly_pred = poly_model.predict(X_poly)
    
    # Sort the values for plotting
    sorted_zip = sorted(zip(scaled_df[feature], y_poly_pred))
    x_sorted, y_poly_pred_sorted = zip(*sorted_zip)
    
    plt.plot(x_sorted, y_poly_pred_sorted, color='red', label='Quadratic')
    plt.xlabel(feature)
    plt.ylabel('Area')
    plt.legend()
    plt.title(f'Fitted Curve - {feature} vs. Area (Quadratic)')
    plt.show()
